# %% [markdown]
# ## Quantum Teleportation: How to send a qubit?

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from funcs import *
import numpy as np
import random
import math

# %% [markdown]
# ## Build Quantum Circuit
#
# ### Step1 : Prepare a  $ \frac{1}{\sqrt{2}}|00\rangle + \frac{1}{\sqrt{2}}|11\rangle $ entanglement. Distribute them to Alice and Bob.

# %%
qc = QuantumCircuit()
q = QuantumRegister(3)
c = ClassicalRegister(3)
qc.add_register(q, c)
r = random.random()
r2 = math.sqrt(1 - r**2)
qc.initialize([r, r2], q[0])
qc.initialize(0, c[0])
qc.initialize(0, c[1])
qc.initialize(0, c[2])
# qc.rz(np.pi/6, q[0])
# qc.h(q[0])
qc.cx(q[1], q[2])
qc.h(q[1])

qc.measure(q[0], c[0])
qc.draw(output='mpl')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 8
#       6 r2 = math.sqrt(1 - r**2)
#       7 qc.initialize([r, r2], q[0])
# ----> 8 qc.initialize(0, c[0])
#       9 qc.initialize(0, c[1])
#      10 qc.initialize(0, c[2])
#
# File d:\ProgramFiles\miniconda\envs\qc\Lib\site-packages\qiskit\circuit\quantumcircuit.py:5810, in QuantumCircuit.initialize(self, params, qubits, normalize)
#    5807 elif isinstance(qubits, (int, np.integer, slice, Qubit)):
#    5808     qubits = [qubits]
# -> 5810 num_qubits = len(qubits) if isinstance(params, int) else None
#    5812 return self.append(Initialize(params, num_qubits, normalize), qubits, copy=False)
#
# TypeError: object of type 'Clbit' has no len()

# %%
results = execute_qc(qc)
print(results)
# Out:
# {'110': 255, '001': 248, '111': 275, '000': 246}

# %% [markdown]
# ### Alice got q1 and Bob got q2. Alice made q1 and q0 (qubit she wanna sent) entangled by CNOT gate.

# %%
qc.cx(q[0], q[1])
qc.h(q[0])

qc.measure(q[0], c[0])
qc.measure(q[1], c[1])
qc.draw(output='mpl')

# %% [markdown]
# ### Bob operates on his own qubit according to information in classical bit

# %%
# control qubits by classical bits
# Attention: you can only do this on a simulator

with qc.if_test((c[1], 1)) as else_:  
    qc.x(q[2])
with qc.if_test((c[0], 1)) as else_:  
    qc.z(q[2])

qc.draw(output='mpl')

# %% [markdown]
# ### Measure q2 to see if it equals original q0

# %%
qc.measure(q[2], c[2])
qc.draw(output='mpl')

# %% [markdown]
# ### execute circuit and process results

# %%
results = execute_qc(qc)
print(results)
counts = [0, 0]
for key, value in results.items(): 
    if key[2]=='0':
        counts[0] += value
    else:
        counts[1] += value
print(counts)
# Out:
# {'001': 261, '110': 247, '111': 273, '000': 243}
# [490, 534]

# %% [markdown]
# ### check if the results are expected

# %% [markdown]
# 测试funcs.py，这里面是我写的一些常用的函数。

# %%
from funcs import *

# %% [markdown]
# 建立一个简单的量子电路

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(2, 2)
qc.h(0)
qc.cx(0, 1)
qc.measure([0, 1], [0, 1])

qc.draw(output='mpl')

# %% [markdown]
# 测试execute_qc，用来执行电路，返回结果

# %%
results = execute_qc(qc)
print(results)
# Out:
# {'00': 504, '11': 520}

# %% [markdown]
# ### test optimize_qc , used to optimize the quantum circuit

# %%
qc = QuantumCircuit(3, 1)
qc.x(0)
qc.x(0)
qc.x(0)
qc.x(1)
qc.x(2)
qc.cx(0, 1)
qc.x(1)
qc.x(1)
qc.draw(output='mpl')

# %%
#for rec in qc.data:
    #print(rec)
    #print(len(rec.qubits))

# %%
qc = optimize_qc(qc)

# %%
qc.draw(output='mpl')
